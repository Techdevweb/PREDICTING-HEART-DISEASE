# %% [markdown]
# # **PREDICTING HEART DISEASE FROM CLINICAL AND LABORATORIAL DATA USING KNN**

# %% [markdown]
# ## **INTRODUCTION**

# %% [markdown]
# Importations:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# Loading the dataset:

# %%
data = pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %% [markdown]
# Shape:

# %%
data.shape
# Out:
# (303, 14)

# %% [markdown]
# Variables types:

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ## **EDA AND PRE-PROCESSING**

# %% [markdown]
# ### Outcome variable count:

# %%
sns.catplot(x='target',kind='count',data=data)

# %% [markdown]
# ### Categorical predictive variables:

# %% [markdown]
# sex:

# %%
sns.catplot(x='sex',kind='count',hue='target',data=data)

# %% [markdown]
# cp:

# %%
sns.catplot(x='cp',hue='target',data=data,kind='count')

# %% [markdown]
# fbs:

# %%
sns.catplot(x='fbs',hue='target',data=data,kind='count')

# %% [markdown]
# restecg:

# %%
sns.catplot(x='restecg',hue='target',data=data,kind='count')

# %% [markdown]
# exang:

# %%
sns.catplot(x='exang',hue='target',data=data,kind='count')

# %% [markdown]
# slope:

# %%
sns.catplot(x='slope',hue='target',data=data,kind='count')

# %% [markdown]
# ca:

# %%
sns.catplot(x='ca',hue='target',data=data,kind='count')

# %% [markdown]
# thal:

# %%
sns.catplot(x='thal',hue='target',data=data,kind='count')

# %% [markdown]
# ### Distributional predictive variables:

# %%
data[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].describe()
# Out:
#               age    trestbps        chol     thalach     oldpeak
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337  131.623762  246.264026  149.646865    1.039604
# std      9.082101   17.538143   51.830751   22.905161    1.161075
# min     29.000000   94.000000  126.000000   71.000000    0.000000
# 25%     47.500000  120.000000  211.000000  133.500000    0.000000
# 50%     55.000000  130.000000  240.000000  153.000000    0.800000
# 75%     61.000000  140.000000  274.500000  166.000000    1.600000
# max     77.000000  200.000000  564.000000  202.000000    6.200000

# %%
sns.displot(x='age',multiple='stack',hue='target',data=data)

# %%
sns.displot(x='trestbps',multiple='stack',hue='target',data=data)

# %%
sns.displot(x='chol',hue='target',data=data,multiple='stack')

# %%
sns.displot(x='thalach',data=data,hue='target',multiple='stack')

# %%
sns.displot(x='oldpeak',hue='target',data=data,multiple='stack')

# %% [markdown]
# ## **SPLITTING AND PRE-PROCESSING:**

# %% [markdown]
# Defining x_train, x_test, y_train and y_test:

# %%
x = data.drop('target',axis=1)
y = data['target']
x_train, x_test, y_train, y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Scaling the data:

# %%
sc = StandardScaler().fit(x_train)
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)
x_train
# Out:
# array([[-1.35679832,  0.72250438,  0.00809909, ...,  0.95390513,
#         -0.68970073, -0.50904773],
#        [ 0.38508599,  0.72250438, -0.97189094, ...,  0.95390513,
#         -0.68970073,  1.17848036],
#        [-0.92132724,  0.72250438,  0.98808912, ..., -0.69498803,
#         -0.68970073, -0.50904773],
#        ...,
#        [ 1.58263146,  0.72250438,  1.96807914, ..., -0.69498803,
#          0.32186034, -0.50904773],
#        [-0.92132724,  0.72250438, -0.97189094, ...,  0.95390513,
#         -0.68970073,  1.17848036],
#        [ 0.92942484, -1.38407465,  0.00809909, ...,  0.95390513,
#          1.33342142, -0.50904773]])

# %% [markdown]
# ## **TRAINING THE MODEL:**

# %% [markdown]
# Parameters for grid search:

# %%
knn = KNeighborsClassifier()
parameters = {'n_neighbors': [3,5,7,9,11], 'weights': ['uniform','distance']}

# %% [markdown]
# Fiting training data and grid searching:

# %%
grid = GridSearchCV(knn,parameters,cv=4,scoring='accuracy')
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=4, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %% [markdown]
# Displayng best parameters:

# %%
print(grid.best_params_)
# Out:
# {'n_neighbors': 5, 'weights': 'uniform'}

# %% [markdown]
# Picking the best model:

# %%
model=grid.best_estimator_

# %% [markdown]
# ## **EVALUATING THE MODEL:**

# %% [markdown]
# Model score on test data:

# %%
model.score(x_test,y_test)
# Out:
# 0.9016393442622951

# %% [markdown]
# Confusion matrix:

# %%
predictions = model.predict(x_test)
cm = metrics.confusion_matrix(y_test,predictions)
cm = pd.DataFrame(cm)
sns.heatmap(cm, annot=True)
plt.show()

# %% [markdown]
# Calculating sensitivity, specificity, PPV and NPV:

# %%
TP = 28
FP = 2
TN = 27
FN = 4
sensitivity = TP/(TP+FN)*100
specificity = TN/(TN+FP)*100
ppv = TP/(TP+FP)*100
npv = TN/(TN+FN)*100

# %% [markdown]
# Printing sensitivity, specificity, PPV and NPV:

# %%
print('Sensitivity:', sensitivity,'% ','Specificity:', specificity,'% ','positive predictive value:',ppv,'% ','negative predictive value:',npv,'%' )
# Out:
# Sensitivity: 87.5 %  Specificity: 93.10344827586206 %  positive predictive value: 93.33333333333333 %  negative predictive value: 87.09677419354838 %

# %% [markdown]
# AUC score:

# %%
probs = model.predict_proba(x_test)[:,1]
auc = metrics.roc_auc_score(y_test,probs)
print(auc)
# Out:
# 0.9154094827586208

# %% [markdown]
# ROC curve:

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,probs)
plt.figure()
plt.grid()
plt.plot(fpr,tpr)
plt.plot([0, 1], [0, 1])
plt.show()
